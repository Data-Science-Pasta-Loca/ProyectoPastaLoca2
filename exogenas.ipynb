# %%
import pandas as pd
import payments_manager as pm
df_jo = pm.df('df_jo')
pd.options.display.max_columns = None
display(df_jo.sort_values(['created_at','created_at_fe']).head(5))
# Out:
#    id_cr  id_fe  fe_cr_id   user_id  active                 created_at  \
# 0      3      0       NaN        47       1 2019-11-19 13:57:53.511561
# 1      4      0       NaN  99001309       0 2019-12-09 14:47:35.190714
# 2      5      0       NaN       804       1 2019-12-10 19:05:21.596873
# 3      6      0       NaN       812       1 2019-12-10 19:05:48.921042
# 4      7      0       NaN       191       1 2019-12-10 19:13:35.825460
#
#   created_at_fe  amount  fee                stat_cr     stat_fe transfer_type  \
# 0           NaT     1.0  0.0               canceled  cr_regular       regular
# 1           NaT   100.0  0.0             money_back  cr_regular       regular
# 2           NaT   100.0  0.0               rejected  cr_regular       regular
# 3           NaT   100.0  0.0  direct_debit_rejected  cr_regular       regular
# 4           NaT   100.0  0.0               rejected  cr_regular       regular
#
# ...
